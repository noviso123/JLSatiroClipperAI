# %% [markdown]
# # 💎 JLSatiro Cobalt - V15.2 (STABLE CPU)
#
# **CLEAN. LIGHT. FAST. ROBUST.**
#
# ---
# ### 🌟 V15.2 - Otimizações de Estabilidade:
# - [x] **Smart Path**: Uso de comandos mágicos `%cd` para garantir que o Colab não se perca.
# - [x] **Direct Install**: Instalação de dependências forçada diretamente no notebook.
# - [x] **Force Drive**: Conexão com Google Drive blindada contra erros de permissão.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Preparar Ambiente (Agora mais robusto).
# 2.  **PASSO 2**: Iniciar Studio.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V15.2 Otimizado) 🔄
import os
import shutil
from google.colab import drive

print("🔍 INICIANDO SISTEMA V15.2 (STRICT CPU)...\n")

# 1. DRIVE - Método mais estável
print("☁️ [1/3] Conectando Nuvem...")
if not os.path.exists('/content/drive'):
    try:
        drive.mount('/content/drive', force_remount=True)
    except Exception as e:
        print(f"⚠️ Aviso Drive: {e}")

# 2. SETUP
print("📦 [2/3] Baixando Aplicação...")
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)

# !git clone {REPO_URL}

# O comando %cd é vital para o Colab manter o foco na pasta correta
# %cd {REPO_DIR}

# 3. INSTALL (Redundância de Segurança)
print("🔧 [3/3] Configurando Motores AI (CPU Only)...")
# Instalando dependências de sistema essenciais para edição de vídeo
# !apt-get update -qq && apt-get install -y ffmpeg > /dev/null
# !pip install -r requirements.txt --quiet

# Executa setup final (apenas checagens)
# !python colab_setup.py

print("\n✅ SISTEMA PRONTO! Vá para o Passo 2.")

# %%
# @title 2. INICIAR STUDIO (V15.2) 💎
print("🔌 Abrindo Interface V15.2 CPU...")
# !python launcher.py
