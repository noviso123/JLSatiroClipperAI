# %% [markdown]
# # 💎 JLSatiro Cobalt - V13.2 (HIGH PERFORMANCE)
#
# **CLEAN. FAST. PRIVATE. POWERFUL.**
#
# ---
# ### 🌟 V13.2 - Edição 12GB RAM:
# - [x] **Big Brain AI**: Substituímos o modelo pequeno pelo **Vosk Large** (1.5GB). Transcrição perfeita.
# - [x] **Max Threads**: FFmpeg configurado para usar todos os núcleos e RAM disponível.
# - [x] **Cache Agressivo**: Buffer de vídeo aumentado para processamento sem engasgos.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala o V13.2 (Vai demorar um pouco mais para baixar o modelo GIGANTE).
# 2.  **PASSO 2**: Roda a Máquina.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V13.2) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V13.2 (HIGH PREFORMANCE)...")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V13.2 (Turbo)...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Dependencias e Modelo Large...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V13.2) 💎
print("🔌 Iniciando Interface V13.2 (PRO)...")
# !python launcher.py
