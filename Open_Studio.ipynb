# %% [markdown]
# # 💎 JLSatiro Cobalt - V14.0 (WHISPER AI EDITION)
#
# **CLEAN. FAST. PRIVATE. POWERFUL.**
#
# ---
# ### 🌟 V14.0 - A Revolução da IA:
# - [x] **Whisper AI (OpenAI)**: Substituímos o Vosk. Agora usamos a IA mais avançada do mundo para legendas.
# - [x] **GPU Acceleration**: Usa a placa de vídeo do Google Colab (T4) para transcrever em segundos.
# - [x] **Zero Downloads**: Não baixa mais arquivos gigantes. O Whisper já vem embutido no ecossistema.
# - [x] **V13.3 Design**: O visual limpo que você já conhece.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala o V14.0 (Whisper Native).
# 2.  **PASSO 2**: Roda a Máquina.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V14.0) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V14.0 (WHISPER EDITION)...\n")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V14.0 (Whisper Upgrade)...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Whisper e Motores...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V14.0) 💎
print("🔌 Iniciando Interface V14.0 (WHISPER NATIVE)...")
# !python launcher.py
