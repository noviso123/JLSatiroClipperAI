# %% [markdown]
# # 🎬 AI Video Clipper Studio - V12.0 (ULTIMATE EDITION)
#
# **ESTÚDIO AUTOMÁTICO DE CORTES VIRAIS**
#
# ---
# ### 🌟 Novidades V12.0 (Final):
# - [x] **API Integration**: Suporte a `client_secret.json` do Google Cloud.
# - [x] **Cookie Persistence**: Salva seus logins para sempre no Drive.
# - [x] **Triple Engine**: O motor de download mais robusto já criado.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala o V12.0 e detecta seu `client_secret.json`.
# 2.  **PASSO 2**: Roda o App.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V12.0) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V12.0 (ULTIMATE)...")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V12.0...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Híbrido com API...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V12.0) 🚀
print("🔌 Iniciando Interface V12.0...")
# !python launcher.py
