# %% [markdown]
# # 💎 JLSatiro Cobalt - V15.6 (UI POLISH)
#
# **CLEAN. LIGHT. FAST. ROBUST.**
#
# ---
# ### 🌟 V15.6 - Limpeza Visual:
# - [x] **No Vosk**: Opção removida da interface.
# - [x] **Correct Labels**: Textos atualizados para refletir modo CPU.
# - [x] **Whisper Locked**: O sistema agora mostra claramente que está usando Whisper (CPU).
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Preparar Ambiente.
# 2.  **PASSO 2**: Iniciar Studio.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V15.6 Final) 🔄
import os
import shutil
from google.colab import drive

print("🔍 INICIANDO SISTEMA V15.6 (UI CLEANUP)...\n")

# 0. SAFE EJECT
# %cd /content

# 1. DRIVE
print("☁️ [1/3] Conectando Nuvem...")
if not os.path.exists('/content/drive'):
    try:
        drive.mount('/content/drive', force_remount=True)
    except Exception as e:
        print(f"⚠️ Aviso Drive: {e}")

# 2. SETUP
print("📦 [2/3] Baixando Aplicação...")
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)

# !git clone {REPO_URL}

# Entra na pasta NOVA
# %cd {REPO_DIR}

# 3. INSTALL
print("🔧 [3/3] Configurando Motores AI (CPU Only)...")
# !apt-get update -qq && apt-get install -y ffmpeg > /dev/null
# !pip install -r requirements.txt --quiet

# !python colab_setup.py

print("\n✅ SISTEMA PRONTO! Vá para o Passo 2.")

# %%
# @title 2. INICIAR STUDIO (V15.6) 💎
print("🔌 Abrindo Interface V15.6 CPU...")
# %cd /content/JLSatiroClipperAI
# !python launcher.py
