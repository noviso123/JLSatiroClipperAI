# %% [markdown]
# # 💎 JLSatiro Cobalt - V15.0 (CPU EDITION)
#
# **CLEAN. LIGHT. FAST. PRIVATE.**
#
# ---
# ### 🌟 V15.0 - Otimização Total (CPU):
# - [x] **Whisper Small**: Modelo ajustado para rodar leve na CPU do Colab.
# - [x] **FFmpeg Fast**: Renderização acelerada com perfil `veryfast`.
# - [x] **Zero GPU**: Não gasta seus créditos de computação.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Preparar Ambiente.
# 2.  **PASSO 2**: Iniciar Studio.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V15.0 CPU) 🔄
import os
import shutil
from google.colab import drive

print("🔍 INICIANDO SISTEMA V15.0 (CPU MODE)...\n")

# 1. DRIVE
print("☁️ [1/3] Conectando Nuvem...")
try:
    drive.mount('/content/drive')
except: pass

# 2. SETUP
print("📦 [2/3] Baixando Aplicação...")
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

# Clean install logic (Silent)
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)

# !git clone {REPO_URL} > /dev/null 2>&1
os.chdir(REPO_DIR)

# 3. INSTALL
print("🔧 [3/3] Configurando Motores AI (CPU)...")
# !python colab_setup.py

print("\n✅ SISTEMA PRONTO! Vá para o Passo 2.")

# %%
# @title 2. INICIAR STUDIO (V15.0) 💎
print("🔌 Abrindo Interface V15.0 CPU...")
# !python launcher.py
