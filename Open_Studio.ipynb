# %% [markdown]
# # 💎 JLSatiro Cobalt - V16.0 (T4 GPU EDITION)
#
# **POWER. PRECISION. SPEED.**
#
# ---
# ### 🌟 V16.0 - Aceleração Máxima:
# - [x] **Whisper Large V3**: O modelo de IA mais avançado do mundo.
# - [x] **GPU T4**: Transcrição quase instantânea com CUDA.
# - [x] **Smart Fallback**: Se a GPU falhar, ele usa a CPU automaticamente.
#
# ### 🚀 Como Usar:
# 1.  **Ative a GPU**: `Ambiente de Execução` -> `Alterar tipo` -> `T4 GPU`.
# 2.  **PASSO 1**: Preparar Ambiente.
# 3.  **PASSO 2**: Iniciar Studio.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V16.0 GPU) 🔄
import os
import shutil
from google.colab import drive

print("🔍 INICIANDO SISTEMA V16.0 (GPU MODE)...\n")

# 0. SAFE EJECT
# %cd /content

# 1. DRIVE
print("☁️ [1/3] Conectando Nuvem...")
if not os.path.exists('/content/drive'):
    try:
        drive.mount('/content/drive', force_remount=True)
    except Exception as e:
        print(f"⚠️ Aviso Drive: {e}")

# 2. SETUP
print("📦 [2/3] Baixando Aplicação...")
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)

# !git clone {REPO_URL}

# Entra na pasta NOVA
# %cd {REPO_DIR}

# 3. INSTALL
print("🔧 [3/3] Configurando Motores AI (GPU T4)...")
# !apt-get update -qq && apt-get install -y ffmpeg > /dev/null
# !pip install -r requirements.txt --quiet

# !python colab_setup.py

print("\n✅ SISTEMA PRONTO! Vá para o Passo 2.")

# %%
# @title 2. INICIAR STUDIO (V16.0) 💎
print("🔌 Abrindo Interface V16.0 GPU...")
# %cd /content/JLSatiroClipperAI
# !python launcher.py
