# %% [markdown]
# # 💎 JLSatiro Cobalt - V14.1 (WHISPER NUCLEAR UPDATER)
#
# **CLEAN. FAST. PRIVATE. POWERFUL.**
#
# ---
# ### 🌟 V14.1 - Correção Crítica:
# - [x] **Force Clean**: Este script apaga a versão antiga (Vosk) e baixa a nova (Whisper) do zero.
# - [x] **Whisper AI**: Ativado e funcionando (Sem downloads de 1.6GB).
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Vai apagar a pasta antiga e baixar a nova. (Pode confiar).
# 2.  **PASSO 2**: Roda a Máquina V14.1.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V14.1 NUCLEAR) ☢️
import os
import shutil
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V14.1 (FORCE CLEAN)...\n")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO (NUCLEAR OPTION)
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("☢️ [2/4] Removendo Versão Antiga (Vosk) para Garantir Whisper...")
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)
    print("   ↳ 🗑️ Versão antiga deletada.")

print("📦 [2.5/4] Baixando Código V14.1 (Whisper Native)...")
# !git clone {REPO_URL}
os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Whisper e Motores...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V14.1) 💎
print("🔌 Iniciando Interface V14.1 (WHISPER NATIVE)...")
# !python launcher.py
