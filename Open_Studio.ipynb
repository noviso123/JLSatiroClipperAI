# %% [markdown]
# # 💎 JLSatiro Cobalt - V15.7 (FINAL STABLE)
#
# **CLEAN. LIGHT. FAST. ROBUST.**
#
# ---
# ### 🌟 V15.7 - Ajuste de Motor:
# - [x] **Smart Downloader**: Correção de erro "Format not available" do YouTube.
# - [x] **CPU Mode**: Whisper Small (461MB) rodando liso.
# - [x] **Interface**: Opções limpas e funcionais.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Preparar Ambiente.
# 2.  **PASSO 2**: Iniciar Studio.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V15.7 Safe) 🔄
import os
import shutil
from google.colab import drive

print("🔍 INICIANDO SISTEMA V15.7 (YTDLP FIX)...\n")

# 0. SAFE EJECT
# %cd /content

# 1. DRIVE
print("☁️ [1/3] Conectando Nuvem...")
if not os.path.exists('/content/drive'):
    try:
        drive.mount('/content/drive', force_remount=True)
    except Exception as e:
        print(f"⚠️ Aviso Drive: {e}")

# 2. SETUP
print("📦 [2/3] Baixando Aplicação...")
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)

# !git clone {REPO_URL}

# Entra na pasta NOVA
# %cd {REPO_DIR}

# 3. INSTALL
print("🔧 [3/3] Configurando Motores AI (CPU Only)...")
# !apt-get update -qq && apt-get install -y ffmpeg > /dev/null
# !pip install -r requirements.txt --quiet

# !python colab_setup.py

print("\n✅ SISTEMA PRONTO! Vá para o Passo 2.")

# %%
# @title 2. INICIAR STUDIO (V15.7) 💎
print("🔌 Abrindo Interface V15.7 CPU...")
# %cd /content/JLSatiroClipperAI
# !python launcher.py
