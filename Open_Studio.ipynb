# %% [markdown]
# # 💎 JLSatiro Cobalt - V13.6 (FINAL STABLE)
#
# **CLEAN. FAST. PRIVATE. POWERFUL.**
#
# ---
# ### 🌟 V13.6 - Release Notes:
# - [x] **URL Fix**: Corrigido link do Modelo Large (FalaBrasil 1.6GB).
# - [x] **Logic Fix**: Instalador agora detecta falhas de rede e ativa Fallback automaticamente.
# - [x] **Cobalt Engine**: `yt-dlp` nativo como motor primário.
# - [x] **Interface**: V13.3 Design (Blue/Ocean).
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala o V13.6 (Pode demorar 1-2min baixando o modelo).
# 2.  **PASSO 2**: Roda a Máquina.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V13.6) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V13.6 (STABLE RELEASE)...\n")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V13.6 (Url Fix)...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Dependencias e Modelos...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V13.6) 💎
print("🔌 Iniciando Interface V13.6 (COBALT CORE)...")
# !python launcher.py
