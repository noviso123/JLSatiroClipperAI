# %% [markdown]
# # 💎 JLSatiro Cobalt - V13.3 (GOLD EDITION)
#
# **CLEAN. FAST. PRIVATE. POWERFUL.**
#
# ---
# ### 🌟 V13.3 - Versão Final (Gold):
# - [x] **Cobalt Engine**: Prioridade total para o `yt-dlp` (o melhor motor do mundo).
# - [x] **Big Brain AI**: Modelo Vosk Large (1.5GB) para transcrição perfeita.
# - [x] **Max Performance**: 16 Threads + Cache Otimizado.
# - [x] **Interface Design**: Visual limpo, premium e sem poluição.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala o V13.3 (Gold).
# 2.  **PASSO 2**: Roda a Máquina.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V13.3) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V13.3 (GOLD)...\n")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V13.3 (Gold Release)...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Dependencias e Modelos...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V13.3) 💎
print("🔌 Iniciando Interface V13.3 (COBALT CORE)...")
# !python launcher.py
