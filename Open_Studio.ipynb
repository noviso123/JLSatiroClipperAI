# %% [markdown]
# # 🎬 AI Video Clipper Studio - V8.0 (STEALTH EDITION)
#
# **ESTÚDIO AUTOMÁTICO DE CORTES VIRAIS**
#
# ---
# ### 🌟 Novidades V8.0:
# - [x] **Modo Stealth**: Simula celular Android para evitar boqueios.
# - [x] **Sem Uploads**: Não precisa mais de cookies.txt nem chaves.
# - [x] **Zero Config**: Interface Gradio simplificada (Só Colar e Rodar).
# - [x] **Furtividade**: IP Mascarado (0.0.0.0) para enganar o YouTube.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala o ambiente V8.0.
# 2.  **PASSO 2**: Roda o App e acessa o link.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V8.0) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V8.0 (STEALTH)...")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V8.0...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Gradio & Engines...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (STEALTH) 🚀
print("🔌 Iniciando Interface V8.0...")
# !python launcher.py
