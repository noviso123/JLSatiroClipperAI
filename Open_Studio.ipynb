# %% [markdown]
# # 🎬 AI Video Clipper Studio - V9.0 (PYTUBEFIX ENGINE)
#
# **ESTÚDIO AUTOMÁTICO DE CORTES VIRAIS**
#
# ---
# ### 🌟 Novidades V9.0:
# - [x] **Nova Engine**: Substituímos `yt-dlp` por `pytubefix`.
# - [x] **Anti-Bloqueio**: Nova estratégia para evitar erro 'Sign in'.
# - [x] **Sem Arquivos**: Funciona sem cookies na maioria dos casos.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Instala tudo (V9.0).
# 2.  **PASSO 2**: Roda o App.
#
# ---

# %%
# @title 1. Sincronizar e Conectar (V9.0) 🔄
import os
from google.colab import drive

print("🔍 AUDITORIA DE SISTEMA V9.0 (PYTUBEFIX)...")

# 1. VERIFICAÇÃO DE DRIVE
print("☁️ [1/4] Verificando Google Drive...")
try:
    drive.mount('/content/drive')
    if os.path.exists('/content/drive/MyDrive'):
        print("✅ Drive Conectado!")
except Exception as e:
    print(f"❌ Erro Drive: {e}")

# 2. ATUALIZAÇÃO DE CÓDIGO
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/4] Baixando Código V9.0...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# 3. INSTALAÇÃO DEPENDECIAS
print("🔧 [3/4] Instalando Gradio & Engines...")
# !python colab_setup.py

print("\n✅ [4/4] TUDO PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR APP (V9.0) 🚀
print("🔌 Iniciando Interface V9.0...")
# !python launcher.py
