# %% [markdown]
# # 💎 JLSatiro Cobalt - V14.2 (WHISPER NATIVE)
#
# **CLEAN. FAST. PRIVATE. POWERFUL.**
#
# ---
# ### 🌟 V14.2 - Whisper Native:
# - [x] **Whisper AI**: Legendas automáticas via GPU (T4).
# - [x] **Cobalt Engine**: Downloads rápidos e seguros.
# - [x] **Design Pro**: Interface limpa e otimizada.
#
# ### 🚀 Como Usar:
# 1.  **PASSO 1**: Preparar Ambiente.
# 2.  **PASSO 2**: Iniciar Studio.
#
# ---

# %%
# @title 1. Sincronizar e Conectar 🔄
import os
import shutil
from google.colab import drive

print("🔍 INICIANDO SISTEMA JLSATIRO V14.2...\n")

# 1. DRIVE
print("☁️ [1/3] Conectando Nuvem...")
try:
    drive.mount('/content/drive')
except: pass

# 2. SETUP
print("📦 [2/3] Baixando Aplicação...")
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

# Clean install logic (Silent)
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR, ignore_errors=True)

# !git clone {REPO_URL} > /dev/null 2>&1
os.chdir(REPO_DIR)

# 3. INSTALL
print("🔧 [3/3] Configurando Motores AI (GPU)...")
# !python colab_setup.py

print("\n✅ SISTEMA PRONTO! Vá para o Passo 2.")

# %%
# @title 2. INICIAR STUDIO 💎
print("🔌 Abrindo Interface V14.2...")
# !python launcher.py
