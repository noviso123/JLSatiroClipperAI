# %% [markdown]
# # 🎬 AI Video Clipper Studio - Ultimate V3.8 (Architecture Update)
#
# **NOVO: Arquitetura Auto-Launcher**
#
# 1.  **Play no Passo 1**: Atualiza o código do GitHub (Garante a última versão).
# 2.  **Play no Passo 2**: Executa o `launcher.py` (Lógica atualizada externa).

# %%
# @title 1. Atualizar e Instalar (Total) 🔄
import os
from google.colab import drive

print("☁️ Conectando ao Google Drive...")
try:
    drive.mount('/content/drive')
except Exception as e:
    print("⚠️ Drive não conectado.")

REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    print("🔄 Buscando nova versão...")
    # !git reset --hard
    # !git pull origin main
else:
    print("⬇️ Clonando projeto...")
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# !python colab_setup.py

# %%
# @title 2. Rodar App (Launcher) 🚀
# Agora a lógica está em 'launcher.py'.
# Isso garante que qualquer atualização no git seja refletida aqui imediatamente.
# !python launcher.py
