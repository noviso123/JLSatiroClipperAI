# %% [markdown]
# # 🎬 AI Video Clipper Studio - V5.0 (Ngrok Edition)
#
# **ESTÚDIO PROFISSIONAL DE CORTES VIRAIS**
#
# ---
# ### 🚀 Instruções:
# 1.  **PASSO 1 (Setup)**: Atualiza o sistema, instala motores e conecta ao **Google Drive**.
# 2.  **PASSO 2 (Iniciar)**: Gera o Link **Ngrok** (Sem senha) para você acessar o App.
#
# ---

# %%
# @title 1. ATUALIZAR E PREPARAR AMBIENTE 🔄☁️
import os
from google.colab import drive

print("VERIFICAÇÃO DE VERSÃO: V5.0 (NGROK-DRIVE-EDITION)")

print("☁️ [1/3] Conectando ao Google Drive...")
try:
    drive.mount('/content/drive')
except Exception as e:
    print("⚠️ Drive não conectado. Rodando em modo temporário.")

# Configuração do Repositório
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/3] Baixando Inteligência do GitHub...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

print("🔧 [3/3] Instalando e Configurando Pastas no Drive...")
# Script externo que faz o Symlink e instala dependências
# !python colab_setup.py

print("\n✅ AMBIENTE PRONTO! Vá para o Passo 2.")

# %%
# @title 2. RODAR ESTÚDIO (Ngrok) 🚀
print("🔌 Iniciando Launcher V5.0...")
# Este script 'launcher.py' contém a chave do Ngrok e a lógica do servidor
# !python launcher.py
