# %% [markdown]
# # 🎬 AI Video Clipper Studio - Ultimate V3.7 (Fixed URL)
#
# **NOVO: URL Fixa (Tentativa)**
#
# 1.  **Play no Passo 1**: Prepara tudo.
# 2.  **Play no Passo 2**: Tenta abrir em `https://viral-clipper-pro.loca.lt`.

# %%
# @title 1. Atualizar e Instalar 🔄
import os
from google.colab import drive

print("☁️ Conectando ao Google Drive...")
try:
    drive.mount('/content/drive')
except Exception as e:
    print("⚠️ Drive não conectado.")

REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    print("🔄 Buscando nova versão...")
    # !git reset --hard
    # !git pull origin main
else:
    print("⬇️ Clonando projeto...")
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# !python colab_setup.py

# %%
# @title 2. Rodar App (URL Customizada) 🚀
import subprocess
import time
from IPython.display import clear_output

print("🔌 Iniciando Servidor...")
get_ipython().system_raw('streamlit run frontend/app.py &')
time.sleep(3)

print("🔗 Tentando reservar URL Fixa: viral-clipper-pro.loca.lt ...")
# Tenta forçar subdomínio. Se falhar, o LT gera um aleatório.
get_ipython().system_raw('lt --port 8501 --subdomain viral-clipper-pro > url.txt 2>&1 &')
time.sleep(5)

print("\n==================================================")
print("🔑 SUA SENHA DO TUNNEL É:")
# !wget -qO - ipv4.icanhazip.com
print("==================================================")

print("\n👇 ACESSE SEU APP:")
# !cat url.txt
print("\n==================================================")
print("ℹ️ Nota: A URL fixa depende da disponibilidade do serviço grátis LocalTunnel.")
