# %% [markdown]
# # 🎬 AI Video Clipper Studio - Ultimate V3
#
# **NOVO: Zero Configuração & Atualizações Totais**
#
# 1.  **Play no Passo 1**: O sistema se atualiza completamente (Código + Dependências).
# 2.  **Play no Passo 2**: O App abre via **LocalTunnel** (Sem conta, sem senhas).

# %%
# @title 1. Atualizar e Instalar (Total Auto-Update) 🔄
import os

REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    print("🔄 Buscando nova versão no GitHub...")
    # !git reset --hard
    # !git pull origin main
else:
    print("⬇️ Clonando projeto...")
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

# Agora rodamos o script de setup que está DENTRO do código baixado.
# Isso garante que se o setup mudar, você recebe a atualização aqui.
# !python colab_setup.py

# %%
# @title 2. Rodar App (Sem Senhas/Keys) 🚀
import subprocess
import time

print("🔌 Iniciando Servidor...")

# 1. Roda o Streamlit em Background
get_ipython().system_raw('streamlit run frontend/app.py &')

# 2. Cria o Túnel com LocalTunnel (Zero Auth)
# Aguarda um pouco para o Streamlit subir
time.sleep(3)
print("🔗 Gerando Link Público (LocalTunnel)...")

# Roda o tunnel na porta 8501 e joga saída num arquivo para lermos a URL
get_ipython().system_raw('lt --port 8501 > url.txt 2>&1 &')

time.sleep(5)

print("\n==================================================")
print("🎉 ACESSE SEU APP AQUI:")
# !cat url.txt
print("==================================================")
print("ℹ️ Se pedir senha 'Tunnel Password', use o IP do Colab (execute: !curl ipv4.icanhazip.com)")
print("ℹ️ Dica: O LocalTunnel é 100% Grátis e não precisa de conta.")
