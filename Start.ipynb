# %% [markdown]
# # 🎬 AI Video Clipper Studio - Versão Final V4.0 (Ngrok Edition)
#
# **Bem-vindo ao seu Estúdio de Cortes Automáticos.**
#
# ---
# ### 🚀 Como Usar:
# 1.  **PASSO 1 (Atualização & Setup)**: Clique no `Play ▶️` abaixo.
#     - Ele vai baixar a última versão do código (GitHub).
#     - Ele vai conectar ao seu **Google Drive** (Para salvar os vídeos).
#     - Ele vai instalar os motores de IA.
#
# 2.  **PASSO 2 (Iniciar App)**: Clique no `Play ▶️` da segunda célula.
#     - Ele vai gerar um **Link Público (Ngrok)**.
#     - **Não precisa de senha**. É só clicar e usar.
#
# ---

# %%
# @title 1. PRÉ-REQUISITOS (Execute 1 vez) 🔄☁️
import os
from google.colab import drive

print("☁️ [1/3] Conectando ao Google Drive (Para salvar seus cortes)...")
try:
    # Monta o Drive para salvar os arquivos finais automaticamente
    drive.mount('/content/drive')
except Exception as e:
    print("⚠️ Drive não conectado. Os arquivos ficarão apenas aqui no Colab.")

# Configuração do Repositório
REPO_URL = "https://github.com/noviso123/JLSatiroClipperAI.git"
REPO_DIR = "/content/JLSatiroClipperAI"

print("📦 [2/3] Baixando/Atualizando Código do Studio...")
if os.path.exists(REPO_DIR):
    os.chdir(REPO_DIR)
    # Força atualização para garantir que você tenha a V4.0
    # !git reset --hard
    # !git pull origin main
else:
    # !git clone {REPO_URL}
    os.chdir(REPO_DIR)

print("🔧 [3/3] Instalando Dependências (Pode levar 30s)...")
# Roda o script de instalação externo (garante dependências sempre novas)
# !python colab_setup.py

print("\n✅ TUDO PRONTO! Vá para o Passo 2 abaixo. 👇")

# %%
# @title 2. INICIAR ESTÚDIO (Ngrok Link) 🚀
# Este comando inicia o 'launcher.py' que gerencia o Ngrok e o App.
# !python launcher.py
